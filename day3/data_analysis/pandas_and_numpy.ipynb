# %%
# pandas bhneko library ho 
# numpy bhneko library ho 
import pandas as pd
import numpy as np

# as np kinw gareko bhneko numpy as np gar bhneko 
# storage kam khanxa and spelling wrong huney chance kam hunxa

#pandas is used for data analysis and manipulation 
# why pandas rather than excecll
# pandas ma bhnyo bhney python use garna milxa ML algorithm use garna milxa 
# millons data bhayo bhney excell ma ramro sanga load huney chance kam hunxa tra pandas ma data haru sab ramro seta load hunxa 
# analysis garda pani excell ma direct python use garnu mildena 
'''
Pandas and Numpy are two essential libraries for data analysis in Python

Pandas:
- Used for data manipulation and analysis
- Handles structured data like CSV, Excel files efficiently 
- Better than Excel for large datasets (millions of rows)
- Integrates well with other Python libraries and ML algorithms
- Provides powerful data analysis tools and functions

Numpy:
- Fundamental package for scientific computing
- Provides support for large multi-dimensional arrays and matrices
- Offers mathematical functions to operate on arrays
- Very efficient for numerical operations
- Forms the foundation for many other scientific Python libraries
- written in C and Fortran so it is very fast
'''
# Out:
# '\nPandas and Numpy are two essential libraries for data analysis in Python\n\nPandas:\n- Used for data manipulation and analysis\n- Handles structured data like CSV, Excel files efficiently \n- Better than Excel for large datasets (millions of rows)\n- Integrates well with other Python libraries and ML algorithms\n- Provides powerful data analysis tools and functions\n\nNumpy:\n- Fundamental package for scientific computing\n- Provides support for large multi-dimensional arrays and matrices\n- Offers mathematical functions to operate on arrays\n- Very efficient for numerical operations\n- Forms the foundation for many other scientific Python libraries\n- written in C and Fortran so it is very fast\n'

# %%
# create a dictionary 
dict1 = {
    'name' : ['John', 'Jane', 'Doe', 'Alice'],
    'marks' : ['40', '50', '60', '80'],
    'city' : ['Kathmandu', 'Butwal', 'Kathmandu', 'Lalitpur']
}

# %%
#convert into dataframe
# dataframe is a two dimensional data structure 
# column and row bata data store hunxa 
# 0 1 2 3 bhneraw index aauxa
df = pd.DataFrame(dict1)
df
# Out:
#     name marks       city
# 0   John    40  Kathmandu
# 1   Jane    50     Butwal
# 2    Doe    60  Kathmandu
# 3  Alice    80   Lalitpur

# %%
# if we need to export the data then
#index remove garnu paryo bhney index=False use garney hai tw 
# yesari data haru .csv file ma save hunxa hai tw 


df.to_csv('data.csv', index=False)

# %%
#aila 4 ota matra row xah paci millions of data auxa 
df.head(2) #dataframee ko first ko row haru aauxa hai tw 
#default value chai 5 hunxa
# Out:
#    name marks       city
# 0  John    40  Kathmandu
# 1  Jane    50     Butwal

# %%
df.tail(2) #dataframee ko last ko row haru aauxa hai tw 
#default value chai 5 hunxa
# Out:
#     name marks       city
# 2    Doe    60  Kathmandu
# 3  Alice    80   Lalitpur

# %%
#we can chagne the value of index too 
df.index = ['first', 'second', 'third', 'fourth']
df
# Out:
#          name marks       city
# first    John    40  Kathmandu
# second   Jane    50     Butwal
# third     Doe    60  Kathmandu
# fourth  Alice    80   Lalitpur

# %%
#data haru read garney load garney 
#mathi chai data lai csv ma convert matra gareko ho hai tw
# tyo heart.xls lai garney ho hai aba

# %%
# data read garnu paryo rw data ma store garyo hai tw 
data = pd.read_csv('heart.xls')
# data = pd.read_csv(r'heart.xls')
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
'''
data.head(10) first 10 rows
data.tail(10) last 10 rows
data.info() data type haru aauxa hai tw 
data.describe() data summary haru aauxa hai tw 
data.shape() data shape haru aauxa hai tw 
data.columns() data columns haru aauxa hai tw 
data.index() data index haru aauxa hai tw 
data.dtypes() data type haru aauxa hai tw 
'''
# Out:
# '\ndata.head(10) first 10 rows\ndata.tail(10) last 10 rows\ndata.info() data type haru aauxa hai tw \ndata.describe() data summary haru aauxa hai tw \ndata.shape() data shape haru aauxa hai tw \ndata.columns() data columns haru aauxa hai tw \ndata.index() data index haru aauxa hai tw \ndata.dtypes() data type haru aauxa hai tw \n'

# %%
#pandas data structures 
'''
Series:
- stores a single colum of data
- One-dimensional array-like object
- Contains data and an index
- Can be thought of as a column in a DataFrame
- Useful for single-column data or simple data manipulation

DataFrame:
- Two-dimensional, size-mutable, and heterogeneous tabular data structure
- Contains rows and columns
- Represents a table with rows and columns
- Most common and flexible data structure in pandas
'''
# Out:
# '\nSeries:\n- stores a single colum of data\n- One-dimensional array-like object\n- Contains data and an index\n- Can be thought of as a column in a DataFrame\n- Useful for single-column data or simple data manipulation\n\nDataFrame:\n- Two-dimensional, size-mutable, and heterogeneous tabular data structure\n- Contains rows and columns\n- Represents a table with rows and columns\n- Most common and flexible data structure in pandas\n'

# %%
ser = pd.Series(np.random.rand(35))
ser
# Out:
# 0     0.246361
# 1     0.056708
# 2     0.487778
# 3     0.679989
# 4     0.479916
# 5     0.187044
# 6     0.109330
# 7     0.468317
# 8     0.225791
# 9     0.126663
# 10    0.572759
# 11    0.846928
# 12    0.279609
# 13    0.814524
# 14    0.585224
# 15    0.343474
# 16    0.691817
# 17    0.683818
# 18    0.296059
# 19    0.267552
# 20    0.058783
# 21    0.535363
# 22    0.764707
# 23    0.090972
# 24    0.276123
# 25    0.854452
# 26    0.522833
# 27    0.148907
# 28    0.656262
# 29    0.200594
# 30    0.308385
# 31    0.762348
# 32    0.173281
# 33    0.435229
# 34    0.418965
# dtype: float64

# %%
df1 = pd.DataFrame(np.random.rand(35,5), index=np.arange(35))
# random rw rand chai random number generate garna use huney model ho hai
# yo 5 bhneko chai colum ho hai 
type(df1)
df1
# Out:
#            0         1         2         3         4
# 0   0.590447  0.139556  0.100125  0.165842  0.860585
# 1   0.817961  0.393046  0.336153  0.176537  0.682571
# 2   0.764960  0.396378  0.337345  0.189313  0.455562
# 3   0.517094  0.387025  0.440544  0.705754  0.290075
# 4   0.910882  0.067193  0.290168  0.785955  0.389273
# 5   0.276558  0.304497  0.681388  0.385067  0.776764
# 6   0.457846  0.507283  0.227208  0.206361  0.474056
# 7   0.277929  0.570874  0.454766  0.611844  0.526171
# 8   0.715875  0.789614  0.648391  0.917966  0.171919
# 9   0.033102  0.028342  0.936101  0.713035  0.594383
# 10  0.359805  0.990735  0.616195  0.960166  0.371560
# 11  0.835019  0.025666  0.487959  0.163741  0.183238
# 12  0.719710  0.170607  0.105565  0.750619  0.484202
# 13  0.081184  0.409008  0.991270  0.298464  0.607901
# 14  0.160536  0.639700  0.934366  0.770974  0.992767
# 15  0.494409  0.856166  0.161540  0.050123  0.865633
# 16  0.881831  0.830542  0.365879  0.908777  0.019370
# ...

# %%
data['age']
# Out:
# 0       52
# 1       53
# 2       70
# 3       61
# 4       62
#         ..
# 1020    59
# 1021    60
# 1022    47
# 1023    50
# 1024    54
# Name: age, Length: 1025, dtype: int64

# %%
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
'''
data haru kasto xah bhneraw herna data head rw tail use garney 
info lae data ko information haru denxa 
'''
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
'''
if we want numerical data then their is a method called describe
tra tesma numerical data matra hunu parxa hai tyo coloum ma chai 
'''
data.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
data.shape
#kati ota rows rw kati ota colum xah bhneraw aauxa hai yesma cchai 
#yo chai method haina yo parameter ho 
#'''
# Out:
# (1025, 14)

# %%
'''
two types of data
1. categorical data
values that can be grouped into categories
typically doesnot have numerical meaning
male = 0 and female = 1
doesnot hold any numerical value
mathi ko example ma chest pain type(1,2,3,4) bhneko categorical data ho 
2 types of categorical data
    1. nominal data
    that doesnot have any usal meaning
    order nabhako random data
    for example : gender(male,female,others), race, color(red,yellow,blur), etc
    2. ordinal data
    that have some ranking and meaningful order
    for example : education level(high school, bachelor, master, doctor), 
                    customer satisfaction(good, better, best), etc
2. continuous data
values that can be measured and have numerical meaning
represent a numerical or any other value
that represent actual numerical value 
mathi ko example ma blood pressure(120,130,140,150) bhneko continuous data ho 

'''
# Out:
# '\ntwo types of data\n1. categorical data\nvalues that can be grouped into categories\ntypically doesnot have numerical meaning\nmale = 0 and female = 1\ndoesnot hold any numerical value\nmathi ko example ma chest pain type(1,2,3,4) bhneko categorical data ho \n2 types of categorical data\n    1. nominal data\n    that doesnot have any usal meaning\n    order nabhako random data\n    for example : gender(male,female,others), race, color(red,yellow,blur), etc\n    2. ordinal data\n    that have some ranking and meaningful order\n    for example : education level(high school, bachelor, master, doctor), \n                    customer satisfaction(good, better, best), etc\n2. continuous data\nvalues that can be measured and have numerical meaning\nrepresent a numerical or any other value\nthat represent actual numerical value \nmathi ko example ma blood pressure(120,130,140,150) bhneko continuous data ho \n\n'

# %%
data.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# ...

# %%
'''
1. age
2. sex
3. cp: chest pain type (4 values)
    - Value 0: typical angina
    - Value 1: atypical angina
    - Value 2: non-angina pain
    - Value 3: asymptomatic
4. trestbps: resting blood pressure(in mm Hg on admission to the hospital
5. chol: serum cholestoral in mg/dl
6. fbs: fasting blood sugar > 120 mg/dl(1=true; 0=false)
7. restecg: resting electrocardiographic results (values 0,1,2)
    - Value 0: normal
    - Value 1: having ST-T wave abnormality (T-wave inversions and/or ST elevation or depression of>0.05 mV)
    - Value 2: Showing probable or definite left ventricular hypertrophy by Estes criteria
8. thalach: maximum heart rate achieved
9. exang: exercise induced angina
10. oldpeak: oldpeak = ST depression induced by exercise relative to rest
11. slope: the slope of the peak exercise ST segment
    - value 1: upsloping
    - value 2: flat
    - value 3: downsloping
12. ca: number of major vessels (0-3) colored by flourosopy
13. thal: 0 = normal; 1 = fixed defect; 2 = reversable defect
14. target: 0=less chance of heart attack, 1= more chance of heart attack
- The names and social security numbers of the patients were recently removed from the database, replaced with dummy values. 
'''
# Out:
# '\n1. age\n2. sex\n3. cp: chest pain type (4 values)\n    - Value 0: typical angina\n    - Value 1: atypical angina\n    - Value 2: non-angina pain\n    - Value 3: asymptomatic\n4. trestbps: resting blood pressure(in mm Hg on admission to the hospital\n5. chol: serum cholestoral in mg/dl\n6. fbs: fasting blood sugar > 120 mg/dl(1=true; 0=false)\n7. restecg: resting electrocardiographic results (values 0,1,2)\n    - Value 0: normal\n    - Value 1: having ST-T wave abnormality (T-wave inversions and/or ST elevation or depression of>0.05 mV)\n    - Value 2: Showing probable or definite left ventricular hypertrophy by Estes criteria\n8. thalach: maximum heart rate achieved\n9. exang: exercise induced angina\n10. oldpeak: oldpeak = ST depression induced by exercise relative to rest\n11. slope: the slope of the peak exercise ST segment\n    - value 1: upsloping\n    - value 2: flat\n    - value 3: downsloping\n12. ca: number of major vessels (0-3) colored by flourosopy\n13. thal: 0 = norma
# ...

# %%
#in continous data we have to detect outliers 
#outliers are data that are significantly different from the rest of the data
#outliers can be caused by data errors, measurement errors, or other factors
#outliers can skew the results of the analysis
#outliers can be detected using statistical methods
#outliers can be removed using statistical methods




#now our next step is data cleaning

# %%
#check whether their is any null value in our data or not 
data.isnull().any()
#return true or false value
#if there is any null value then it will return true otherwise false
#.any garyo bhney age ma null value bhye true return garxa batra false 
# yeslae and use garxa 
#right now we dont have any null value in our data
# Out:
# age         False
# sex         False
# cp          False
# trestbps    False
# chol        False
# fbs         False
# restecg     False
# thalach     False
# exang       False
# oldpeak     False
# slope       False
# ca          False
# thal        False
# target      False
# dtype: bool

# %%
#now lets check the data is duplicate or not
# data duplicate garera sakesamma model lai train nagrney 
#yedi data kam bhyo bhney balla duplicate use garney jastai scientific research haru ma 
data[data.duplicated()]
# this return the duplicate data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 15     34    0   1       118   210    0        1      192      0      0.7
# 31     50    0   1       120   244    0        1      162      0      1.1
# 43     46    1   0       120   249    0        0      144      0      0.8
# 55     55    1   0       140   217    0        1      111      1      5.6
# 61     66    0   2       146   278    0        0      152      0      0.0
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 15        2   0     2       1
# ...

# %%
data.duplicated(subset=['age']).any()
# this return the duplicate data
# Out:
# np.True_

# %%
data.drop_duplicates()
#this doesnot change the original data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %%
data = data.drop_duplicates()
data
#data.drop_duplicates(inplace=True)
#this change the original data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %%
data.duplicated().any()
#we have removed the duplicated data
# Out:
# np.False_

# %%
#value count bhney method hunxa arko 
#unique value kati ota xah count garxa 
#jastai age 53 xah bhney 53 kati choti repeat bhnyo bhneraw aauxa 
#paticular colum ma use garney ho hai 
data['age'].value_counts()
#can also return the occerance
# Out:
# age
# 58    19
# 57    17
# 54    16
# 59    14
# 52    13
# 51    12
# 60    11
# 62    11
# 44    11
# 56    11
# 64    10
# 41    10
# 63     9
# 67     9
# 53     8
# 61     8
# 55     8
# 65     8
# 45     8
# 42     8
# 43     8
# 48     7
# 46     7
# 66     7
# 50     7
# 47     5
# 49     5
# 70     4
# 35     4
# 39     4
# 68     4
# 69     3
# 71     3
# 40     3
# 34     2
# 38     2
# 37     2
# 29     1
# 76     1
# 77     1
# 74     1
# Name: count, dtype: int64

# %%
data['sex'].value_counts()
#assume 0 = female and 1 = male 
#hence there are 206 male and 96 female after removing the duplicates
# Out:
# sex
# 1    206
# 0     96
# Name: count, dtype: int64

# %%
#finds unique method 
#unique method returns the unique charatcters, variables or values in the datasets
data['thal'].unique()
#this return the unique value in array
# Out:
# array([3, 2, 1, 0])

# %%
data['sex'].unique()
# 1 = male and 0 = female
# Out:
# array([1, 0])

# %%
# check wheather the male or female is visiting more often 
data['sex'].value_counts()
# Out:
# sex
# 1    206
# 0     96
# Name: count, dtype: int64

# %%
#here more are male visiting more often to the hospital so we can conclude that there is high chance for male to have heart disease

# %%
#data filter garney hai paila 
#filter bhneko certain condition lagyeraw data lai extract garney 

# There are multiple errors in this line:
# 1. It's value_counts() not value.counts() - missing underscore
# 2. Can't use age>40 directly - need to reference the column 
# 3. The logical condition syntax is incorrect

# The correct way would be:
data[data['age']>40]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %%
data[data['chol']<200]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 2     70    1   0       145   174    0        1      125      1      2.6
# 10    71    0   0       112   149    0        1      125      0      1.6
# 20    60    1   2       140   185    0        0      155      0      3.0
# 30    44    1   0       120   169    0        1      144      1      2.8
# 32    57    1   0       130   131    0        1      115      1      1.2
# 34    50    1   2       129   196    0        1      163      0      0.0
# 52    38    1   2       138   175    0        1      173      0      0.0
# 53    49    1   2       120   188    0        1      139      0      2.0
# 56    56    1   3       120   193    0        0      162      0      1.9
# 66    53    1   2       130   197    1        0      152      0      1.2
# 69    62    0   0       160   164    0        0      145      0      6.2
# 73    59    1   0       140   177    0        1      162      1      0.0
# ...

# %%
(data['age']>40).sum()
#this sums boolean value only
# Out:
# np.int64(284)

# %%
# The error is that we can't use 'and' operator directly with pandas Series
# We need to use & operator and wrap conditions in parentheses

((data['age']>40) & (data['age']<50)).sum()
# Out:
# np.int64(69)

# %%
data['age'].value_counts()
# Out:
# age
# 58    19
# 57    17
# 54    16
# 59    14
# 52    13
# 51    12
# 60    11
# 62    11
# 44    11
# 56    11
# 64    10
# 41    10
# 63     9
# 67     9
# 53     8
# 61     8
# 55     8
# 65     8
# 45     8
# 42     8
# 43     8
# 48     7
# 46     7
# 66     7
# 50     7
# 47     5
# 49     5
# 70     4
# 35     4
# 39     4
# 68     4
# 69     3
# 71     3
# 40     3
# 34     2
# 38     2
# 37     2
# 29     1
# 76     1
# 77     1
# 74     1
# Name: count, dtype: int64

# %%
# (data[' age']>40).value_counts()
# yo chai error hunxa hai 
# value_count() lae kati choti repeat bhako xah matra bhnxa hai

# %%
#determine the shape, info of dataset
#find the person whose chol is greater than

# %%
data.shape
# Out:
# (302, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 302 entries, 0 to 878
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       302 non-null    int64
#  1   sex       302 non-null    int64
#  2   cp        302 non-null    int64
#  3   trestbps  302 non-null    int64
#  4   chol      302 non-null    int64
#  5   fbs       302 non-null    int64
#  6   restecg   302 non-null    int64
#  7   thalach   302 non-null    int64
#  8   exang     302 non-null    int64
#  9   oldpeak   302 non-null    float64
#  10  slope     302 non-null    int64
#  11  ca        302 non-null    int64
#  12  thal      302 non-null    int64
#  13  target    302 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 35.4 KB

# %%
data[(data['chol']>200)]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# 5     58    0   0       100   248    0        0      122      0      1.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 719   52    1   0       108   233    1        1      147      0      0.1
# 720   64    1   2       140   335    0        1      158      0      0.0
# 723   68    0   2       120   211    0        0      115      0      1.5
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %%
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %%
data.isnull()
# Out:
#        age    sex     cp  trestbps   chol    fbs  restecg  thalach  exang  \
# 0    False  False  False     False  False  False    False    False  False
# 1    False  False  False     False  False  False    False    False  False
# 2    False  False  False     False  False  False    False    False  False
# 3    False  False  False     False  False  False    False    False  False
# 4    False  False  False     False  False  False    False    False  False
# ..     ...    ...    ...       ...    ...    ...      ...      ...    ...
# 723  False  False  False     False  False  False    False    False  False
# 733  False  False  False     False  False  False    False    False  False
# 739  False  False  False     False  False  False    False    False  False
# 843  False  False  False     False  False  False    False    False  False
# 878  False  False  False     False  False  False    False    False  False
#
#      oldpeak  slope     ca   thal  target
# ...

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df
# Out:
#          name marks       city
# first    John    40  Kathmandu
# second   Jane    50     Butwal
# third     Doe    60  Kathmandu
# fourth  Alice    80   Lalitpur

# %%
data['age'].mean()
#this calculate the mean of the age column
# Out:
# np.float64(54.420529801324506)

# %%
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %%
data['thalach'].median()
#replace the most repeated data in categorical data but in numerical data replace with mean(if there is null value)
# Out:
# np.float64(152.5)

# %%
data['sex'].mode()
# Out:
# 0    1
# Name: sex, dtype: int64

# %%
data.duplicated().any()
# Out:
# np.False_

# %%
#mathi ko basic ho hai tw 
# hami seta bhako data chai already clean data cah hai tw

# %%
data.dtypes
# return the types of the column
#model train garauda ki int ki float ma convert garaunu parxa hai tw jasai
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
# two colums are involved in a single condition 
# on the basis of age i want to find the cholestrol level 
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64
