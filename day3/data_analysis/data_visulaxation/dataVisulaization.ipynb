# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('datavisualized.xls')

# %%
df
# Out:
#            Date     Month  Year Product_Category  Revenue  Profit  Expenses  \
# 0    01/01/2023     March  2023      Electronics    36822   12890     21542
# 1    01/02/2023  November  2023         Clothing    40126    7460     26847
# 2    01/03/2023  December  2023      Electronics    39693   15282     22076
# 3    01/04/2023  December  2023         Clothing    23050   15248     17382
# 4    01/05/2023      June  2023        Furniture    42728   19490     27631
# ..          ...       ...   ...              ...      ...     ...       ...
# 995  09/22/2025  November  2023      Electronics    32484    8011     41845
# 996  09/23/2025    August  2023      Electronics    20795    7931     39341
# 997  09/24/2025    August  2023      Electronics    53710    5389     11113
# 998  09/25/2025   January  2023      Electronics    63383    6235     46539
# 999  09/26/2025     April  2023      Electronics    67248    6133     10343
#
#      Customer_Age Customer_Gender Region  Sales_Volume
# 0              53            Male  North           123
# 1              58          Female  South           191
# 2              41          Female  North           180
# 3              36            Male  North           214
# 4              45            Male   East           230
# ..            ...             ...    ...           ...
# 995            26          Female  South            98
# 996            20            Male   West           241
# 997            43          Female  North            52
# 998            36          Female  South           147
# 999            27            Male  North           143
#
# [1000 rows x 11 columns]

# %%
#Line plot
#certain time ma kasto trend xah bhneraw herna milxa 
'''
purpose:
1. to TRACK change over time peroid 
2 . to the relationship between two variables(continuous data )
3. seasonal pattern

Structure: 
    x axis ma independent variable (time)
    y axis ma dependent variable (intrest rate, sales, etc)
    data catogerical bhayo bhney bar plot use garney line plot avoid garney
'''
# Out:
# '\npurpose:\n1. to TRACK change over time peroid \n2 . to the relationship between two variables(continuous data )\n3. seasonal pattern\n\nStructure: \n    x axis ma independent variable (time)\n    y axis ma dependent variable (intrest rate, sales, etc)\n    data catogerical bhayo bhney bar plot use garney line plot avoid garney\n'

# %%
plt.plot(df['Profit'], df['Sales_Volume'])

# %%
df1 = df.head(20)
df1
# Out:
#           Date      Month  Year Product_Category  Revenue  Profit  Expenses  \
# 0   01/01/2023      March  2023      Electronics    36822   12890     21542
# 1   01/02/2023   November  2023         Clothing    40126    7460     26847
# 2   01/03/2023   December  2023      Electronics    39693   15282     22076
# 3   01/04/2023   December  2023         Clothing    23050   15248     17382
# 4   01/05/2023       June  2023        Furniture    42728   19490     27631
# 5   01/06/2023    January  2023         Clothing    38757    8091     16797
# 6   01/07/2023  September  2023         Clothing    67876    6473     16706
# 7   01/08/2023       July  2023         Clothing    66542    5930     40159
# 8   01/09/2023        May  2023      Electronics    65006    8872     10661
# 9   01/10/2023       June  2023      Electronics    45004   19341     24266
# 10  01/11/2023        May  2023      Electronics    65188   13986     45867
# 11  01/12/2023   November  2023        Furniture    34764   13194     12347
# 12  01/13/2023     August  2023        Furniture    44992   11761     17026
# 13  01/14/2023        May  2023      Electronics    46992    7676     12082
# 14  01/15/2023   February  2023         Clothing    22412   12276     26854
# 15  01/16/2023      April  2023        Furniture    50214   16393     18790
# 16  01/17/2023   February  2023        Furniture    41256   19068     15540
# 17  01/18/2023       July  2023        Furniture    51919    6882     17952
# 18  01/19/2023     August  2023      Electronics    30290   11283     12140
# 19  01/20/2023  September  2023      Electronics    45276   19142     32947
#
#     Customer_Age Customer_Gender Region  Sales_Volume
# 0             53            Male  North           123
# 1             58          Female  South           191
# 2             41          Female  North           180
# 3             36            Male  North           214
# 4             45            Male   East           230
# 5             39            Male   West           132
# 6             23          Female   West           150
# 7             21            Male  South           232
# 8             40          Female  North           146
# 9             30            Male  South           139
# 10            53          Female   West           297
# 11            60          Female   East           228
# 12            60            Male   East           254
# 13            37          Female  South           163
# 14            54            Male   East           286
# 15            59          Female   East           225
# 16            25          Female  South           114
# 17            44          Female   East           143
# 18            22          Female  North           213
# 19            38          Female  South           113

# %%
#figure size deda jaila plot bhnda mathi garney hai tw 
plt.figure(figsize=(15,5))
plt.plot(df1['Date'], df1['Sales_Volume'],marker = 'o', c= 'r', label= 'Sales_Volume')
plt.xlabel('Date',fontsize= 10, color= 'blue', style= 'italic')
plt.ylabel('Sales_Volume',fontsize= 10, color= 'blue', style= 'italic')
plt.title('Sales_Volume over Time', fontsize= 15)
plt.grid(True)
#grid lae box haru ma dekhauxa 
plt.legend()
plt.xticks(rotation= 45)
plt.show()

# %%
#count plot and bar plot 
# bar plot 
''' 
kasto type ko data legney: 
compare values across different categories
we can use categoriacal data and continuous data 
 purpose:
    1. to compare quantities -> compare values across different groups
    2. also use to the distribution of a categorical data
Structure:
    x axis ma categorical data 
    y axis ma continuous data 
Example: 
    different age group ko manxey 
    college ko aadhar ma passing rate
'''
# Out:
# ' \nkasto type ko data legney: \ncompare values across different categories\nwe can use categoriacal data and continuous data \n purpose:\n    1. to compare quantities -> compare values across different groups\n    2. also use to the distribution of a categorical data\nStructure:\n    x axis ma categorical data \n    y axis ma continuous data \nExample: \n    different age group ko manxey \n    college ko aadhar ma passing rate\n'

# %%
plt.bar(df['Product_Category'], df['Profit'], edgecolor= 'black')
plt.xlabel('Product_Category',fontsize= 10, color= 'blue', style= 'italic')
plt.ylabel('Profit',fontsize= 10, color= 'blue', style= 'italic')
plt.title('Profit by Product_Category', fontsize= 15)
plt.xticks(rotation= 45)
plt.show()

#what does edgecolor do?
#edgecolor is used to set the color of the edge of the bars.

#task edgecolor = ' black what does it do? why it is essential?
#edgecolor = ' black' is used to set the color of the edge of the bars to black.
#it is essential because it helps to make the bars more visible and distinct from the background.

#task 2: 
#task 2:

# %%
#count plot 
'''
'''
count = df['Product_Category'].value_counts().reset_index()
count.plot(kind = 'bar', color = 'green')
plt.xlabel('Product_Category',fontsize= 10, color= 'blue', style= 'italic')
plt.ylabel('Count',fontsize= 10, color= 'blue', style= 'italic')
plt.title('Count of Product_Category', fontsize= 15)
plt.xticks(rotation= 45)
plt.show()

# %%
sns.countplot(data = df, x = 'Product_Category', palette='pastel')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11796\3865861823.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = df, x = 'Product_Category', palette='pastel')
# <Axes: xlabel='Product_Category', ylabel='count'>
